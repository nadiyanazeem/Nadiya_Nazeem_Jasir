# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('car_age_price.csv')
df
# Out:
#      Year   Price
# 0    2018  465000
# 1    2019  755000
# 2    2019  700000
# 3    2018  465000
# 4    2018  465000
# ..    ...     ...
# 107  2016  375000
# 108  2014  300000
# 109  2015  425000
# 110  2016  420000
# 111  2015  425000
#
# [112 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    112 non-null    int64
#  1   Price   112 non-null    int64
# dtypes: int64(2)
# memory usage: 1.9 KB

# %%
df.shape
# Out:
# (112, 2)

# %%
df.isna().sum()
# Out:
# Year     0
# Price    0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#      Year   Price
# 3    2018  465000
# 4    2018  465000
# 9    2017  575000
# 15   2017  500000
# 16   2017  500000
# 18   2019  500000
# 19   2017  500000
# 20   2018  500000
# 21   2019  500000
# 23   2017  550000
# 24   2017  550000
# 25   2017  550000
# 26   2017  550000
# 27   2017  550000
# 28   2017  550000
# 29   2017  550000
# 31   2017  550000
# 32   2017  550000
# 33   2017  550000
# 35   2017  550000
# 36   2017  550000
# 41   2019  600000
# 44   2019  550000
# 46   2019  500000
# 47   2018  450000
# 51   2018  550000
# 53   2013  345000
# 55   2017  550000
# 57   2017  550000
# 62   2017  540000
# 64   2015  490000
# 66   2017  525000
# 72   2015  300000
# 74   2017  490000
# 75   2017  490000
# 76   2015  450000
# 79   2015  400000
# 82   2015  390000
# 84   2015  325000
# 87   2017  520000
# 88   2017  520000
# 89   2017  520000
# 90   2017  520000
# 91   2017  520000
# 92   2017  520000
# 93   2017  520000
# 94   2017  520000
# 95   2017  520000
# 96   2017  520000
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (58, 2)

# %% [markdown]
# # Linear Regression Model

# %%
x=df.drop(["Price"],axis=1) ## independent variable
y = df['Price']## dependent Variable
x
# Out:
#      Year
# 0    2018
# 1    2019
# 2    2019
# 5    2015
# 6    2016
# 7    2017
# 8    2017
# 10   2019
# 11   2018
# 12   2017
# 13   2019
# 14   2017
# 17   2017
# 22   2015
# 30   2019
# 34   2017
# 37   2017
# 38   2018
# 39   2020
# 40   2019
# 42   2018
# 43   2019
# 45   2018
# 48   2016
# 49   2018
# 50   2013
# 52   2013
# 54   2017
# 56   2014
# 58   2014
# 59   2016
# 60   2015
# 61   2017
# 63   2017
# 65   2017
# 67   2015
# 68   2015
# 69   2015
# 70   2015
# 71   2017
# 73   2013
# 77   2015
# 78   2015
# 80   2015
# 81   2014
# 83   2017
# 85   2015
# 86   2017
# 97   2020
# 98   2020
# 99   2020
# 100  2016
# 103  2017
# 104  2014
# 107  2016
# 108  2014
# 109  2015
# 110  2016

# %%
y
# Out:
# 0      465000
# 1      755000
# 2      700000
# 5      350000
# 6      425000
# 7      575000
# 8      509999
# 10     500000
# 11     500000
# 12     500000
# 13     600000
# 14     475000
# 17     550000
# 22     434999
# 30     650000
# 34     450000
# 37     486000
# 38     475000
# 39     545000
# 40     525000
# 42     550000
# 43     550000
# 45     450000
# 48     396000
# 49     600000
# 50     325000
# 52     345000
# 54     525000
# 56     341000
# 58     450000
# 59     550000
# 60     490000
# 61     540000
# 63     595000
# 65     495000
# 67     400000
# 68     465000
# 69     300000
# 70     450000
# 71     490000
# 73     320000
# 77     325000
# 78     409999
# 80     390000
# 81     390000
# 83     480000
# 85     320000
# 86     520000
# 97     640000
# 98     700000
# 99     600000
# 100    350000
# 103    375000
# 104    400000
# 107    375000
# 108    300000
# 109    425000
# 110    420000
# Name: Price, dtype: int64

# %% [markdown]
# # Linear Regression

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size= 0.2,random_state= 42)

# %%
from sklearn.linear_model import LinearRegression
lin_regressor = LinearRegression()
model = lin_regressor.fit(x_train,y_train)

# %%
predictions = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score
print ('MSE =',mean_squared_error(y_test,predictions))
print('R squared value = ',r2_score(y_test,predictions))
# Out:
# MSE = 4578558064.883415
# R squared value =  0.5952655854274035

# %% [markdown]
# # Lasso Regression`

# %%
from sklearn.linear_model import Lasso
lasso=Lasso()
ls_model=lasso.fit(x_train,y_train)

# %%
ls_predict=ls_model.predict(x_test)

# %%
print("Mean Squared Error=",mean_squared_error(y_test,ls_predict))
print("R Squared Error=",r2_score(y_test,ls_predict))
# Out:
# Mean Squared Error= 4578570510.946484
# R Squared Error= 0.5952644852229334

# %% [markdown]
# # Possible price of a 2022 model second-hand grand i10

# %%
yr_2022=pd.DataFrame({'Year':[2022]})

# %%
yr_2022
# Out:
#    Year
# 0  2022

# %%
predict_2022=model.predict(yr_2022)

# %%
predict_2022
# Out:
# array([717501.61505376])

# %%
print("Possible price of 2022 model second hand grand i10 is :",predict_2022)
# Out:
# Possible price of 2022 model second hand grand i10 is : [717501.61505376]
